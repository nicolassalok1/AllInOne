# %% [markdown]
# # 🚀 Pipeline Heston Complet dans un Notebook
#
# Ce notebook reprend la logique de `streamlit_app.py` et déroule les étapes :
# 1. Téléchargement des données d'options via Yahoo Finance.
# 2. Calibration des paramètres Heston par réseau de neurones PyTorch.
# 3. Calcul de surfaces d'IV analytiques par Carr-Madan puis inversion Black-Scholes.
# 4. Pricing Monte Carlo Heston et comparaison vs les prix analytiques.
#
# Exécutez les cellules séquentiellement pour reproduire l'analyse complète.

# %% [markdown]
# ## Pré-requis
# - Installer les dépendances : `pip install -r requirements.txt`
# - Une clé réseau active pour que `yfinance` récupère les options en direct.
# - GPU facultatif (le script tourne sur CPU).

# %%
from __future__ import annotations

import math
import requests
import re
from pathlib import Path
from typing import Callable, Dict, Tuple

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import torch
import yfinance as yf
from IPython.display import display
from scipy.interpolate import griddata

from heston_torch import HestonParams, carr_madan_call_torch

torch.set_default_dtype(torch.float64)
DEVICE = torch.device("cpu")
MIN_IV_MATURITY = 0.1

# %% [markdown]
# ## Fonctions utilitaires : marché et simulation Monte Carlo

# %%
def heston_mc_pricer(
    S0: float,
    K: float,
    T: float,
    r: float,
    v0: float,
    theta: float,
    kappa: float,
    sigma_v: float,
    rho: float,
    n_paths: int = 50_000,
    n_steps: int = 100,
    option_type: str = "call",
) -> float:
    """Pricer Monte Carlo pour options européennes sous Heston."""
    dt = T / n_steps
    sqrt_dt = math.sqrt(dt)

    S = np.full(n_paths, S0)
    v = np.full(n_paths, v0)

    for _ in range(n_steps):
        Z1 = np.random.randn(n_paths)
        Z2 = np.random.randn(n_paths)
        Z_S = Z1
        Z_v = rho * Z1 + math.sqrt(1 - rho**2) * Z2

        S = S * np.exp((r - 0.5 * np.maximum(v, 0)) * dt + np.sqrt(np.maximum(v, 0)) * sqrt_dt * Z_S)
        v = v + kappa * (theta - np.maximum(v, 0)) * dt + sigma_v * np.sqrt(np.maximum(v, 0)) * sqrt_dt * Z_v
        v = np.maximum(v, 0)

    payoff = np.maximum(S - K, 0) if option_type == "call" else np.maximum(K - S, 0)
    return math.exp(-r * T) * np.mean(payoff)


def fetch_spot(symbol: str) -> float:
    ticker = yf.Ticker(symbol)
    hist = ticker.history(period="1d")
    if hist.empty:
        raise RuntimeError("Unable to retrieve spot price.")
    return float(hist["Close"].iloc[-1])


def _select_monthly_expirations(expirations, years_ahead: float = 2.5) -> list[str]:
    today = pd.Timestamp.utcnow().date()
    limit_date = today + pd.Timedelta(days=365 * years_ahead)
    monthly: Dict[Tuple[int, int], Tuple[pd.Timestamp, str]] = {}
    for exp in expirations:
        exp_ts = pd.Timestamp(exp)
        exp_date = exp_ts.date()
        if not (today < exp_date <= limit_date):
            continue
        key = (exp_date.year, exp_date.month)
        if key not in monthly or exp_ts < monthly[key][0]:
            monthly[key] = (exp_ts, exp)
    return [item[1] for item in sorted(monthly.values(), key=lambda x: x[0])]


def download_options(symbol: str, option_type: str, years_ahead: float = 2.5, save_csv: bool = True) -> pd.DataFrame:
    ticker = yf.Ticker(symbol)
    spot = fetch_spot(symbol)
    expirations = ticker.options
    if not expirations:
        raise RuntimeError(f"No option expirations found for {symbol}")
    selected = _select_monthly_expirations(expirations, years_ahead)
    rows: list[dict] = []
    now = pd.Timestamp.utcnow().tz_localize(None)
    for expiry in selected:
        expiry_dt = pd.Timestamp(expiry)
        T = max((expiry_dt - now).total_seconds() / (365.0 * 24 * 3600), 0.0)
        chain = ticker.option_chain(expiry)
        data = chain.calls if option_type == "call" else chain.puts
        price_col = "C_mkt" if option_type == "call" else "P_mkt"
        for _, row in data.iterrows():
            rows.append(
                {
                    "S0": spot,
                    "K": float(row["strike"]),
                    "T": T,
                    price_col: float(row["lastPrice"]),
                    "iv_market": float(row.get("impliedVolatility", float("nan"))),
                }
            )
    df = pd.DataFrame(rows)
    if save_csv:
        out_dir = Path("data")
        out_dir.mkdir(parents=True, exist_ok=True)
        ts = pd.Timestamp.utcnow().strftime("%Y%m%d_%H%M%S")
        out_path = out_dir / f"{symbol}_{option_type}_options_{ts}.csv"
        df.to_csv(out_path, index=False)
        print(f"Options {option_type} sauvegardées dans {out_path}")
    return df

# %% [markdown]
# ## Calibration Heston NN et fonctions Black-Scholes

# %%
def prices_from_unconstrained(
    u: torch.Tensor,
    S0_t: torch.Tensor,
    K_t: torch.Tensor,
    T_t: torch.Tensor,
    r: float,
    q: float,
) -> torch.Tensor:
    params = HestonParams.from_unconstrained(u[0], u[1], u[2], u[3], u[4])
    prices = []
    for S0_i, K_i, T_i in zip(S0_t, K_t, T_t):
        price_i = carr_madan_call_torch(S0_i, r, q, T_i, params, K_i)
        prices.append(price_i)
    return torch.stack(prices)


def loss(
    u: torch.Tensor,
    S0_t: torch.Tensor,
    K_t: torch.Tensor,
    T_t: torch.Tensor,
    C_mkt_t: torch.Tensor,
    r: float,
    q: float,
) -> torch.Tensor:
    model_prices = prices_from_unconstrained(u, S0_t, K_t, T_t, r, q)
    diff = model_prices - C_mkt_t
    return 0.5 * (diff**2).mean()


def calibrate_heston_nn(
    df: pd.DataFrame,
    r: float,
    q: float,
    max_points: int = 1000,
    max_iters: int = 200,
    lr: float = 5e-3,
    progress_callback: Callable[[int, int], None] | None = None,
    log_callback: Callable[[str], None] | None = None,
    display_every: int = 10,
) -> dict:
    if df.empty:
        raise ValueError("DataFrame vide.")

    df_clean = df.dropna(subset=["S0", "K", "T", "C_mkt"])
    df_clean = df_clean[df_clean["T"] > 0]
    df_clean = df_clean[df_clean["C_mkt"] > 0]

    if len(df_clean) == 0:
        raise ValueError("Aucun point valide après nettoyage.")

    if len(df_clean) > max_points:
        df_clean = df_clean.sample(n=max_points, random_state=42)

    S0_t = torch.tensor(df_clean["S0"].values, dtype=torch.float64, device=DEVICE)
    K_t = torch.tensor(df_clean["K"].values, dtype=torch.float64, device=DEVICE)
    T_t = torch.tensor(df_clean["T"].values, dtype=torch.float64, device=DEVICE)
    C_mkt_t = torch.tensor(df_clean["C_mkt"].values, dtype=torch.float64, device=DEVICE)

    u = torch.zeros(5, dtype=torch.float64, device=DEVICE, requires_grad=True)
    optimizer = torch.optim.Adam([u], lr=lr)

    for iteration in range(max_iters):
        optimizer.zero_grad()
        loss_val = loss(u, S0_t, K_t, T_t, C_mkt_t, r, q)
        loss_val.backward()
        optimizer.step()

        if progress_callback:
            progress_callback(iteration + 1, max_iters)
        if log_callback:
            log_callback(f"Iter {iteration + 1}/{max_iters} | Loss = {loss_val.item():.6f}")
        elif (iteration + 1) % display_every == 0 or iteration == 0:
            print(f"Iter {iteration + 1}/{max_iters} | Loss = {loss_val.item():.6f}")

    params = HestonParams.from_unconstrained(u[0], u[1], u[2], u[3], u[4])

    return {
        "kappa": float(params.kappa.cpu().detach()),
        "theta": float(params.theta.cpu().detach()),
        "sigma": float(params.sigma.cpu().detach()),
        "rho": float(params.rho.cpu().detach()),
        "v0": float(params.v0.cpu().detach()),
    }


def bs_call(S: float, K: float, T: float, r: float, sigma: float) -> float:
    if T <= 0 or sigma <= 0:
        return max(S - K, 0)
    d1 = (math.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * math.sqrt(T))
    d2 = d1 - sigma * math.sqrt(T)
    from scipy.stats import norm
    return S * norm.cdf(d1) - K * math.exp(-r * T) * norm.cdf(d2)


def bs_put(S: float, K: float, T: float, r: float, sigma: float) -> float:
    if T <= 0 or sigma <= 0:
        return max(K - S, 0)
    d1 = (math.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * math.sqrt(T))
    d2 = d1 - sigma * math.sqrt(T)
    from scipy.stats import norm
    return K * math.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)


def implied_vol_option(
    price: float,
    S: float,
    K: float,
    T: float,
    r: float,
    option_type: str = "call",
    tol: float = 1e-6,
    max_iter: int = 100,
) -> float:
    if T < MIN_IV_MATURITY:
        return np.nan

    intrinsic = max(S - K, 0) if option_type == "call" else max(K - S, 0)
    if price <= intrinsic:
        return np.nan

    sigma = 0.3
    for _ in range(max_iter):
        price_est = bs_call(S, K, T, r, sigma) if option_type == "call" else bs_put(S, K, T, r, sigma)
        diff = price_est - price
        if abs(diff) < tol:
            return sigma

        d1 = (math.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * math.sqrt(T))
        from scipy.stats import norm
        vega = S * norm.pdf(d1) * math.sqrt(T)
        if vega < 1e-10:
            return np.nan

        sigma = sigma - diff / vega
        if sigma <= 0:
            return np.nan

    return np.nan

# %% [markdown]
# ## Paramètres de la session

# %%
ticker = "SPY"
rf_rate = 0.02
div_yield = 0.0
years_ahead = 2.5
iv_T_max = 2.0  # Horizon max pour la surface IV (T grid)
calib_T_target = 0.86  # Maturité utilisée pour la calibration ciblée
calib_span = 10  # Bande K autour de S0 pour la calibration
T_mc = 0.86
span_mc = 20.0
span_k_grid = span_mc  # Span utilisé pour filtrer les strikes autour de S0 (K = +/- span)
step_strike = 1.0
n_maturities = 40
n_paths = 5000
max_iters = 1000
max_points = 1_000
learning_rate = 0.005
use_cboe_data = True  # Activer la récupération via CBOE delayed (gratuit)
cboe_save_call = "data/testcall.csv"
cboe_save_put = "data/testput.csv"

print(f"Ticker = {ticker} | r = {rf_rate:.2%} | q = {div_yield:.2%}")
# Out:
# Ticker = SPY | r = 2.00% | q = 0.00%

# %% [markdown]
# ## Étape 0 — CBOE delayed (gratuit)
#
# Fonction utilitaire pour récupérer la chaîne d'options CBOE (données retardées 15 min) et sauvegarder dans `data/testcall.csv` / `data/testput.csv`.

# %%
def download_options_cboe(symbol: str, option_type: str = "call", save_csv: bool = True, out_path: str | None = None):
    # Chaîne d'options via CBOE delayed (gratuite) sans filtre K
    import numpy as np  # import local pour éviter les surprises

    url = f"https://cdn.cboe.com/api/global/delayed_quotes/options/{symbol.upper()}.json"
    resp = requests.get(url, timeout=10)
    resp.raise_for_status()
    payload = resp.json()
    data = payload.get("data", {})
    options = data.get("options", [])
    spot = float(data.get("current_price") or data.get("close") or np.nan)

    now = pd.Timestamp.utcnow().tz_localize(None)
    pattern = re.compile(rf"^{symbol.upper()}(?P<expiry>\d{{6}})(?P<cp>[CP])(?P<strike>\d+)$")

    rows: list[dict] = []
    for opt in options:
        opt_code = opt.get("option", "")
        match = pattern.match(opt_code)
        if not match:
            continue
        cp = match.group("cp")
        if (option_type == "call" and cp != "C") or (option_type == "put" and cp != "P"):
            continue

        expiry_dt = pd.to_datetime(match.group("expiry"), format="%y%m%d")
        T = (expiry_dt - now).total_seconds() / (365.0 * 24 * 3600)
        if T <= 0:
            continue
        T = round(T, 2)
        if T <= 0:
            continue

        strike = int(match.group("strike")) / 1000.0

        bid = float(opt.get("bid") or 0.0)
        ask = float(opt.get("ask") or 0.0)
        last = float(opt.get("last_trade_price") or 0.0)
        mid = np.nan
        if bid > 0 and ask > 0:
            mid = 0.5 * (bid + ask)
        elif last > 0:
            mid = last
        mid = round(mid, 2)
        if np.isnan(mid) or mid <= 0:
            continue

        iv_val = opt.get("iv", np.nan)
        iv_val = float(iv_val) if iv_val not in (None, "") else np.nan

        rows.append({
            "S0": spot,
            "K": strike,
            "T": T,
            "C_mkt": mid if option_type == "call" else np.nan,
            "P_mkt": mid if option_type == "put" else np.nan,
            "iv_market": iv_val,
        })

    df = pd.DataFrame(rows)
    if save_csv:
        target = Path(out_path or f"data/test{'call' if option_type == 'call' else 'put'}.csv")
        target.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(target, index=False)
        print(f"CBOE {option_type} sauvegardé dans {target} ({len(df)} lignes)")
    return df, spot

# %% [markdown]
# ## Étape 1 — Téléchargement des options
#
# Deux jeux de données sont construits :
# - `calls_df_full` / `puts_df_full` téléchargés (complets).
# - `calls_df_train` / `puts_df_train` identiques (pas de filtre K appliqué).

# %%
if use_cboe_data:
    print("Mode CBOE delayed activé (gratuit)…")
    calls_df_full, S0_ref = download_options_cboe(ticker, "call", save_csv=True, out_path=cboe_save_call)
    puts_df_full, _ = download_options_cboe(ticker, "put", save_csv=True, out_path=cboe_save_put)
else:
    calls_df_full = download_options(ticker, "call", years_ahead)
    puts_df_full = download_options(ticker, "put", years_ahead)
    S0_ref = fetch_spot(ticker)

# Arrondi des maturités au centième
calls_df_full["T"] = calls_df_full["T"].round(2)
puts_df_full["T"] = puts_df_full["T"].round(2)
# Suppression des maturités nulles
calls_df_full = calls_df_full[calls_df_full["T"] > 0]
puts_df_full = puts_df_full[puts_df_full["T"] > 0]

# Jeux d'entraînement = datasets complets
calls_df_train = calls_df_full.copy()
puts_df_train = puts_df_full.copy()

# Alias utilisés par la suite
calls_df = calls_df_train
puts_df = puts_df_train

print(f"Calls (train complet) : {len(calls_df_train)} | Puts (train complet) : {len(puts_df_train)}")
print(f"Spot S0 = {S0_ref:.2f}")

display(calls_df_train.head())

# Sauvegarde des datasets (train)
calls_df_train.to_csv(cboe_save_call, index=False)
puts_df_train.to_csv(cboe_save_put, index=False)
print(f"Training calls sauvegardés dans {cboe_save_call} ({len(calls_df_train)} lignes)")
print(f"Training puts sauvegardés dans {cboe_save_put} ({len(puts_df_train)} lignes)")
# Out:
# Mode CBOE delayed activé (gratuit)…
# CBOE call sauvegardé dans data/testcall.csv (4739 lignes)
# CBOE put sauvegardé dans data/testput.csv (4742 lignes)
# Calls (train complet) : 4739 | Puts (train complet) : 4742
# Spot S0 = 672.97
#        S0      K     T   C_mkt  P_mkt  iv_market
# 0  672.97  500.0  0.01  162.90    NaN     0.0000
# 1  672.97  505.0  0.01  157.92    NaN     0.7300
# 2  672.97  510.0  0.01  152.92    NaN     0.6013
# 3  672.97  515.0  0.01  147.93    NaN     0.6739
# 4  672.97  520.0  0.01  142.93    NaN     0.6262
# Training calls sauvegardés dans data/testcall.csv (4739 lignes)
# Training puts sauvegardés dans data/testput.csv (4742 lignes)

# %% [markdown]
# ## Étape 2 — Calibration Heston NN

# %%
def notebook_progress(current: int, total: int) -> None:
    pct = 100 * current / total
    print(f"Progression: {pct:5.1f}% ({current}/{total})")

# Calibration sur la zone d'intérêt (T ≈ calib_T_target, K dans [S0_ref - calib_span, S0_ref + calib_span])
calib_slice = calls_df_train[
    (calls_df_train["T"].round(2) == round(calib_T_target, 2)) &
    (calls_df_train["K"].between(S0_ref - calib_span, S0_ref + calib_span)) &
    (calls_df_train["C_mkt"] > 0.05) &
    (calls_df_train["iv_market"] > 0)
]

print(f"Calibration sur {len(calib_slice)} points (T≈{calib_T_target}, K in [{S0_ref - calib_span:.1f}, {S0_ref + calib_span:.1f}])")
if len(calib_slice) < 5:
    raise ValueError("Pas assez de points pour calibrer dans cette zone.")

calib_params = calibrate_heston_nn(
    calib_slice,
    r=rf_rate,
    q=div_yield,
    max_points=max_points,
    max_iters=max_iters,
    lr=learning_rate,
    progress_callback=notebook_progress,
)

print("Paramètres Heston calibrés:")
display(pd.Series(calib_params, name="valeur"))
# Out:
# Calibration sur 20 points (T≈0.86, K in [663.0, 683.0])
# Progression:   0.1% (1/1000)
# Iter 1/1000 | Loss = 11673.909665
# Progression:   0.2% (2/1000)
# Progression:   0.3% (3/1000)
# Progression:   0.4% (4/1000)
# Progression:   0.5% (5/1000)
# Progression:   0.6% (6/1000)
# Progression:   0.7% (7/1000)
# Progression:   0.8% (8/1000)
# Progression:   0.9% (9/1000)
# Progression:   1.0% (10/1000)
# Iter 10/1000 | Loss = 11121.234418
# Progression:   1.1% (11/1000)
# Progression:   1.2% (12/1000)
# Progression:   1.3% (13/1000)
# Progression:   1.4% (14/1000)
# Progression:   1.5% (15/1000)
# Progression:   1.6% (16/1000)
# Progression:   1.7% (17/1000)
# Progression:   1.8% (18/1000)
# Progression:   1.9% (19/1000)
# Progression:   2.0% (20/1000)
# Iter 20/1000 | Loss = 10521.046981
# Progression:   2.1% (21/1000)
# Progression:   2.2% (22/1000)
# Progression:   2.3% (23/1000)
# Progression:   2.4% (24/1000)
# Progression:   2.5% (25/1000)
# Progression:   2.6% (26/1000)
# Progression:   2.7% (27/1000)
# Progression:   2.8% (28/1000)
# Progression:   2.9% (29/1000)
# Progression:   3.0% (30/1000)
# Iter 30/1000 | Loss = 9937.139566
# Progression:   3.1% (31/1000)
# Progression:   3.2% (32/1000)
# Progression:   3.3% (33/1000)
# Progression:   3.4% (34/1000)
# Progression:   3.5% (35/1000)
# Progression:   3.6% (36/1000)
# Progression:   3.7% (37/1000)
# Progression:   3.8% (38/1000)
# Progression:   3.9% (39/1000)
# Progression:   4.0% (40/1000)
# Iter 40/1000 | Loss = 9370.477319
# Progression:   4.1% (41/1000)
# Progression:   4.2% (42/1000)
# Progression:   4.3% (43/1000)
# Progression:   4.4% (44/1000)
# Progression:   4.5% (45/1000)
# Progression:   4.6% (46/1000)
# Progression:   4.7% (47/1000)
# Progression:   4.8% (48/1000)
# Progression:   4.9% (49/1000)
# Progression:   5.0% (50/1000)
# Iter 50/1000 | Loss = 8821.426751
# Progression:   5.1% (51/1000)
# Progression:   5.2% (52/1000)
# Progression:   5.3% (53/1000)
# Progression:   5.4% (54/1000)
# Progression:   5.5% (55/1000)
# Progression:   5.6% (56/1000)
# Progression:   5.7% (57/1000)
# Progression:   5.8% (58/1000)
# Progression:   5.9% (59/1000)
# Progression:   6.0% (60/1000)
# Iter 60/1000 | Loss = 8290.007667
# Progression:   6.1% (61/1000)
# Progression:   6.2% (62/1000)
# Progression:   6.3% (63/1000)
# Progression:   6.4% (64/1000)
# Progression:   6.5% (65/1000)
# Progression:   6.6% (66/1000)
# Progression:   6.7% (67/1000)
# Progression:   6.8% (68/1000)
# Progression:   6.9% (69/1000)
# Progression:   7.0% (70/1000)
# Iter 70/1000 | Loss = 7776.107004
# Progression:   7.1% (71/1000)
# Progression:   7.2% (72/1000)
# Progression:   7.3% (73/1000)
# Progression:   7.4% (74/1000)
# Progression:   7.5% (75/1000)
# Progression:   7.6% (76/1000)
# Progression:   7.7% (77/1000)
# Progression:   7.8% (78/1000)
# Progression:   7.9% (79/1000)
# Progression:   8.0% (80/1000)
# Iter 80/1000 | Loss = 7279.620037
# Progression:   8.1% (81/1000)
# Progression:   8.2% (82/1000)
# Progression:   8.3% (83/1000)
# Progression:   8.4% (84/1000)
# Progression:   8.5% (85/1000)
# Progression:   8.6% (86/1000)
# Progression:   8.7% (87/1000)
# Progression:   8.8% (88/1000)
# Progression:   8.9% (89/1000)
# Progression:   9.0% (90/1000)
# Iter 90/1000 | Loss = 6800.531858
# Progression:   9.1% (91/1000)
# Progression:   9.2% (92/1000)
# Progression:   9.3% (93/1000)
# Progression:   9.4% (94/1000)
# Progression:   9.5% (95/1000)
# Progression:   9.6% (96/1000)
# Progression:   9.7% (97/1000)
# Progression:   9.8% (98/1000)
# Progression:   9.9% (99/1000)
# Progression:  10.0% (100/1000)
# Iter 100/1000 | Loss = 6338.959058
# Progression:  10.1% (101/1000)
# Progression:  10.2% (102/1000)
# Progression:  10.3% (103/1000)
# Progression:  10.4% (104/1000)
# Progression:  10.5% (105/1000)
# Progression:  10.6% (106/1000)
# Progression:  10.7% (107/1000)
# Progression:  10.8% (108/1000)
# Progression:  10.9% (109/1000)
# Progression:  11.0% (110/1000)
# Iter 110/1000 | Loss = 5895.164258
# Progression:  11.1% (111/1000)
# Progression:  11.2% (112/1000)
# Progression:  11.3% (113/1000)
# Progression:  11.4% (114/1000)
# Progression:  11.5% (115/1000)
# Progression:  11.6% (116/1000)
# Progression:  11.7% (117/1000)
# Progression:  11.8% (118/1000)
# Progression:  11.9% (119/1000)
# Progression:  12.0% (120/1000)
# Iter 120/1000 | Loss = 5469.548899
# Progression:  12.1% (121/1000)
# Progression:  12.2% (122/1000)
# Progression:  12.3% (123/1000)
# Progression:  12.4% (124/1000)
# Progression:  12.5% (125/1000)
# Progression:  12.6% (126/1000)
# Progression:  12.7% (127/1000)
# Progression:  12.8% (128/1000)
# Progression:  12.9% (129/1000)
# Progression:  13.0% (130/1000)
# Iter 130/1000 | Loss = 5062.626211
# Progression:  13.1% (131/1000)
# Progression:  13.2% (132/1000)
# Progression:  13.3% (133/1000)
# Progression:  13.4% (134/1000)
# Progression:  13.5% (135/1000)
# Progression:  13.6% (136/1000)
# Progression:  13.7% (137/1000)
# Progression:  13.8% (138/1000)
# Progression:  13.9% (139/1000)
# Progression:  14.0% (140/1000)
# Iter 140/1000 | Loss = 4674.976227
# Progression:  14.1% (141/1000)
# Progression:  14.2% (142/1000)
# Progression:  14.3% (143/1000)
# Progression:  14.4% (144/1000)
# Progression:  14.5% (145/1000)
# Progression:  14.6% (146/1000)
# Progression:  14.7% (147/1000)
# Progression:  14.8% (148/1000)
# Progression:  14.9% (149/1000)
# Progression:  15.0% (150/1000)
# Iter 150/1000 | Loss = 4307.186755
# Progression:  15.1% (151/1000)
# Progression:  15.2% (152/1000)
# Progression:  15.3% (153/1000)
# Progression:  15.4% (154/1000)
# Progression:  15.5% (155/1000)
# Progression:  15.6% (156/1000)
# Progression:  15.7% (157/1000)
# Progression:  15.8% (158/1000)
# Progression:  15.9% (159/1000)
# Progression:  16.0% (160/1000)
# Iter 160/1000 | Loss = 3959.786850
# Progression:  16.1% (161/1000)
# Progression:  16.2% (162/1000)
# Progression:  16.3% (163/1000)
# Progression:  16.4% (164/1000)
# Progression:  16.5% (165/1000)
# Progression:  16.6% (166/1000)
# Progression:  16.7% (167/1000)
# Progression:  16.8% (168/1000)
# Progression:  16.9% (169/1000)
# Progression:  17.0% (170/1000)
# Iter 170/1000 | Loss = 3633.181218
# Progression:  17.1% (171/1000)
# Progression:  17.2% (172/1000)
# Progression:  17.3% (173/1000)
# Progression:  17.4% (174/1000)
# Progression:  17.5% (175/1000)
# Progression:  17.6% (176/1000)
# Progression:  17.7% (177/1000)
# Progression:  17.8% (178/1000)
# Progression:  17.9% (179/1000)
# Progression:  18.0% (180/1000)
# Iter 180/1000 | Loss = 3327.594216
# Progression:  18.1% (181/1000)
# Progression:  18.2% (182/1000)
# Progression:  18.3% (183/1000)
# Progression:  18.4% (184/1000)
# Progression:  18.5% (185/1000)
# Progression:  18.6% (186/1000)
# Progression:  18.7% (187/1000)
# Progression:  18.8% (188/1000)
# Progression:  18.9% (189/1000)
# Progression:  19.0% (190/1000)
# Iter 190/1000 | Loss = 3043.030444
# Progression:  19.1% (191/1000)
# Progression:  19.2% (192/1000)
# Progression:  19.3% (193/1000)
# Progression:  19.4% (194/1000)
# Progression:  19.5% (195/1000)
# Progression:  19.6% (196/1000)
# Progression:  19.7% (197/1000)
# Progression:  19.8% (198/1000)
# Progression:  19.9% (199/1000)
# Progression:  20.0% (200/1000)
# Iter 200/1000 | Loss = 2779.255871
# Progression:  20.1% (201/1000)
# Progression:  20.2% (202/1000)
# Progression:  20.3% (203/1000)
# Progression:  20.4% (204/1000)
# Progression:  20.5% (205/1000)
# Progression:  20.6% (206/1000)
# Progression:  20.7% (207/1000)
# Progression:  20.8% (208/1000)
# Progression:  20.9% (209/1000)
# Progression:  21.0% (210/1000)
# Iter 210/1000 | Loss = 2535.799884
# Progression:  21.1% (211/1000)
# Progression:  21.2% (212/1000)
# Progression:  21.3% (213/1000)
# Progression:  21.4% (214/1000)
# Progression:  21.5% (215/1000)
# Progression:  21.6% (216/1000)
# Progression:  21.7% (217/1000)
# Progression:  21.8% (218/1000)
# Progression:  21.9% (219/1000)
# Progression:  22.0% (220/1000)
# Iter 220/1000 | Loss = 2311.975515
# Progression:  22.1% (221/1000)
# Progression:  22.2% (222/1000)
# Progression:  22.3% (223/1000)
# Progression:  22.4% (224/1000)
# Progression:  22.5% (225/1000)
# Progression:  22.6% (226/1000)
# Progression:  22.7% (227/1000)
# Progression:  22.8% (228/1000)
# Progression:  22.9% (229/1000)
# Progression:  23.0% (230/1000)
# Iter 230/1000 | Loss = 2106.913024
# Progression:  23.1% (231/1000)
# Progression:  23.2% (232/1000)
# Progression:  23.3% (233/1000)
# Progression:  23.4% (234/1000)
# Progression:  23.5% (235/1000)
# Progression:  23.6% (236/1000)
# Progression:  23.7% (237/1000)
# Progression:  23.8% (238/1000)
# Progression:  23.9% (239/1000)
# Progression:  24.0% (240/1000)
# Iter 240/1000 | Loss = 1919.601234
# Progression:  24.1% (241/1000)
# Progression:  24.2% (242/1000)
# Progression:  24.3% (243/1000)
# Progression:  24.4% (244/1000)
# Progression:  24.5% (245/1000)
# Progression:  24.6% (246/1000)
# Progression:  24.7% (247/1000)
# Progression:  24.8% (248/1000)
# Progression:  24.9% (249/1000)
# Progression:  25.0% (250/1000)
# Iter 250/1000 | Loss = 1748.931303
# Progression:  25.1% (251/1000)
# Progression:  25.2% (252/1000)
# Progression:  25.3% (253/1000)
# Progression:  25.4% (254/1000)
# Progression:  25.5% (255/1000)
# Progression:  25.6% (256/1000)
# Progression:  25.7% (257/1000)
# Progression:  25.8% (258/1000)
# Progression:  25.9% (259/1000)
# Progression:  26.0% (260/1000)
# Iter 260/1000 | Loss = 1593.738680
# Progression:  26.1% (261/1000)
# Progression:  26.2% (262/1000)
# Progression:  26.3% (263/1000)
# Progression:  26.4% (264/1000)
# Progression:  26.5% (265/1000)
# Progression:  26.6% (266/1000)
# Progression:  26.7% (267/1000)
# Progression:  26.8% (268/1000)
# Progression:  26.9% (269/1000)
# Progression:  27.0% (270/1000)
# Iter 270/1000 | Loss = 1452.840296
# Progression:  27.1% (271/1000)
# Progression:  27.2% (272/1000)
# Progression:  27.3% (273/1000)
# Progression:  27.4% (274/1000)
# Progression:  27.5% (275/1000)
# Progression:  27.6% (276/1000)
# Progression:  27.7% (277/1000)
# Progression:  27.8% (278/1000)
# Progression:  27.9% (279/1000)
# Progression:  28.0% (280/1000)
# Iter 280/1000 | Loss = 1325.065410
# Progression:  28.1% (281/1000)
# Progression:  28.2% (282/1000)
# Progression:  28.3% (283/1000)
# Progression:  28.4% (284/1000)
# Progression:  28.5% (285/1000)
# Progression:  28.6% (286/1000)
# Progression:  28.7% (287/1000)
# Progression:  28.8% (288/1000)
# Progression:  28.9% (289/1000)
# Progression:  29.0% (290/1000)
# Iter 290/1000 | Loss = 1209.279571
# Progression:  29.1% (291/1000)
# Progression:  29.2% (292/1000)
# Progression:  29.3% (293/1000)
# Progression:  29.4% (294/1000)
# Progression:  29.5% (295/1000)
# Progression:  29.6% (296/1000)
# Progression:  29.7% (297/1000)
# Progression:  29.8% (298/1000)
# Progression:  29.9% (299/1000)
# Progression:  30.0% (300/1000)
# Iter 300/1000 | Loss = 1104.401982
# Progression:  30.1% (301/1000)
# Progression:  30.2% (302/1000)
# Progression:  30.3% (303/1000)
# Progression:  30.4% (304/1000)
# Progression:  30.5% (305/1000)
# Progression:  30.6% (306/1000)
# Progression:  30.7% (307/1000)
# Progression:  30.8% (308/1000)
# Progression:  30.9% (309/1000)
# Progression:  31.0% (310/1000)
# Iter 310/1000 | Loss = 1009.417010
# Progression:  31.1% (311/1000)
# Progression:  31.2% (312/1000)
# Progression:  31.3% (313/1000)
# Progression:  31.4% (314/1000)
# Progression:  31.5% (315/1000)
# Progression:  31.6% (316/1000)
# Progression:  31.7% (317/1000)
# Progression:  31.8% (318/1000)
# Progression:  31.9% (319/1000)
# Progression:  32.0% (320/1000)
# Iter 320/1000 | Loss = 923.380812
# Progression:  32.1% (321/1000)
# Progression:  32.2% (322/1000)
# Progression:  32.3% (323/1000)
# Progression:  32.4% (324/1000)
# Progression:  32.5% (325/1000)
# Progression:  32.6% (326/1000)
# Progression:  32.7% (327/1000)
# Progression:  32.8% (328/1000)
# Progression:  32.9% (329/1000)
# Progression:  33.0% (330/1000)
# Iter 330/1000 | Loss = 845.424103
# Progression:  33.1% (331/1000)
# Progression:  33.2% (332/1000)
# Progression:  33.3% (333/1000)
# Progression:  33.4% (334/1000)
# Progression:  33.5% (335/1000)
# Progression:  33.6% (336/1000)
# Progression:  33.7% (337/1000)
# Progression:  33.8% (338/1000)
# Progression:  33.9% (339/1000)
# Progression:  34.0% (340/1000)
# Iter 340/1000 | Loss = 774.752024
# Progression:  34.1% (341/1000)
# Progression:  34.2% (342/1000)
# Progression:  34.3% (343/1000)
# Progression:  34.4% (344/1000)
# Progression:  34.5% (345/1000)
# Progression:  34.6% (346/1000)
# Progression:  34.7% (347/1000)
# Progression:  34.8% (348/1000)
# Progression:  34.9% (349/1000)
# Progression:  35.0% (350/1000)
# Iter 350/1000 | Loss = 710.641942
# Progression:  35.1% (351/1000)
# Progression:  35.2% (352/1000)
# Progression:  35.3% (353/1000)
# Progression:  35.4% (354/1000)
# Progression:  35.5% (355/1000)
# Progression:  35.6% (356/1000)
# Progression:  35.7% (357/1000)
# Progression:  35.8% (358/1000)
# Progression:  35.9% (359/1000)
# Progression:  36.0% (360/1000)
# Iter 360/1000 | Loss = 652.439862
# Progression:  36.1% (361/1000)
# Progression:  36.2% (362/1000)
# Progression:  36.3% (363/1000)
# Progression:  36.4% (364/1000)
# Progression:  36.5% (365/1000)
# Progression:  36.6% (366/1000)
# Progression:  36.7% (367/1000)
# Progression:  36.8% (368/1000)
# Progression:  36.9% (369/1000)
# Progression:  37.0% (370/1000)
# Iter 370/1000 | Loss = 599.555993
# Progression:  37.1% (371/1000)
# Progression:  37.2% (372/1000)
# Progression:  37.3% (373/1000)
# Progression:  37.4% (374/1000)
# Progression:  37.5% (375/1000)
# Progression:  37.6% (376/1000)
# Progression:  37.7% (377/1000)
# Progression:  37.8% (378/1000)
# Progression:  37.9% (379/1000)
# Progression:  38.0% (380/1000)
# Iter 380/1000 | Loss = 551.459872
# Progression:  38.1% (381/1000)
# Progression:  38.2% (382/1000)
# Progression:  38.3% (383/1000)
# Progression:  38.4% (384/1000)
# Progression:  38.5% (385/1000)
# Progression:  38.6% (386/1000)
# Progression:  38.7% (387/1000)
# Progression:  38.8% (388/1000)
# Progression:  38.9% (389/1000)
# Progression:  39.0% (390/1000)
# Iter 390/1000 | Loss = 507.675340
# Progression:  39.1% (391/1000)
# Progression:  39.2% (392/1000)
# Progression:  39.3% (393/1000)
# Progression:  39.4% (394/1000)
# Progression:  39.5% (395/1000)
# Progression:  39.6% (396/1000)
# Progression:  39.7% (397/1000)
# Progression:  39.8% (398/1000)
# Progression:  39.9% (399/1000)
# Progression:  40.0% (400/1000)
# Iter 400/1000 | Loss = 467.775587
# Progression:  40.1% (401/1000)
# Progression:  40.2% (402/1000)
# Progression:  40.3% (403/1000)
# Progression:  40.4% (404/1000)
# Progression:  40.5% (405/1000)
# Progression:  40.6% (406/1000)
# Progression:  40.7% (407/1000)
# Progression:  40.8% (408/1000)
# Progression:  40.9% (409/1000)
# Progression:  41.0% (410/1000)
# Iter 410/1000 | Loss = 431.378382
# Progression:  41.1% (411/1000)
# Progression:  41.2% (412/1000)
# Progression:  41.3% (413/1000)
# Progression:  41.4% (414/1000)
# Progression:  41.5% (415/1000)
# Progression:  41.6% (416/1000)
# Progression:  41.7% (417/1000)
# Progression:  41.8% (418/1000)
# Progression:  41.9% (419/1000)
# Progression:  42.0% (420/1000)
# Iter 420/1000 | Loss = 398.141596
# Progression:  42.1% (421/1000)
# Progression:  42.2% (422/1000)
# Progression:  42.3% (423/1000)
# Progression:  42.4% (424/1000)
# Progression:  42.5% (425/1000)
# Progression:  42.6% (426/1000)
# Progression:  42.7% (427/1000)
# Progression:  42.8% (428/1000)
# Progression:  42.9% (429/1000)
# Progression:  43.0% (430/1000)
# Iter 430/1000 | Loss = 367.759051
# Progression:  43.1% (431/1000)
# Progression:  43.2% (432/1000)
# Progression:  43.3% (433/1000)
# Progression:  43.4% (434/1000)
# Progression:  43.5% (435/1000)
# Progression:  43.6% (436/1000)
# Progression:  43.7% (437/1000)
# Progression:  43.8% (438/1000)
# Progression:  43.9% (439/1000)
# Progression:  44.0% (440/1000)
# Iter 440/1000 | Loss = 339.956711
# Progression:  44.1% (441/1000)
# Progression:  44.2% (442/1000)
# Progression:  44.3% (443/1000)
# Progression:  44.4% (444/1000)
# Progression:  44.5% (445/1000)
# Progression:  44.6% (446/1000)
# Progression:  44.7% (447/1000)
# Progression:  44.8% (448/1000)
# Progression:  44.9% (449/1000)
# Progression:  45.0% (450/1000)
# Iter 450/1000 | Loss = 314.489235
# Progression:  45.1% (451/1000)
# Progression:  45.2% (452/1000)
# Progression:  45.3% (453/1000)
# Progression:  45.4% (454/1000)
# Progression:  45.5% (455/1000)
# Progression:  45.6% (456/1000)
# Progression:  45.7% (457/1000)
# Progression:  45.8% (458/1000)
# Progression:  45.9% (459/1000)
# Progression:  46.0% (460/1000)
# Iter 460/1000 | Loss = 291.136857
# Progression:  46.1% (461/1000)
# Progression:  46.2% (462/1000)
# Progression:  46.3% (463/1000)
# Progression:  46.4% (464/1000)
# Progression:  46.5% (465/1000)
# Progression:  46.6% (466/1000)
# Progression:  46.7% (467/1000)
# Progression:  46.8% (468/1000)
# Progression:  46.9% (469/1000)
# Progression:  47.0% (470/1000)
# Iter 470/1000 | Loss = 269.702591
# Progression:  47.1% (471/1000)
# Progression:  47.2% (472/1000)
# Progression:  47.3% (473/1000)
# Progression:  47.4% (474/1000)
# Progression:  47.5% (475/1000)
# Progression:  47.6% (476/1000)
# Progression:  47.7% (477/1000)
# Progression:  47.8% (478/1000)
# Progression:  47.9% (479/1000)
# Progression:  48.0% (480/1000)
# Iter 480/1000 | Loss = 250.009729
# Progression:  48.1% (481/1000)
# Progression:  48.2% (482/1000)
# Progression:  48.3% (483/1000)
# Progression:  48.4% (484/1000)
# Progression:  48.5% (485/1000)
# Progression:  48.6% (486/1000)
# Progression:  48.7% (487/1000)
# Progression:  48.8% (488/1000)
# Progression:  48.9% (489/1000)
# Progression:  49.0% (490/1000)
# Iter 490/1000 | Loss = 231.899620
# Progression:  49.1% (491/1000)
# Progression:  49.2% (492/1000)
# Progression:  49.3% (493/1000)
# Progression:  49.4% (494/1000)
# Progression:  49.5% (495/1000)
# Progression:  49.6% (496/1000)
# Progression:  49.7% (497/1000)
# Progression:  49.8% (498/1000)
# Progression:  49.9% (499/1000)
# Progression:  50.0% (500/1000)
# Iter 500/1000 | Loss = 215.229681
# Progression:  50.1% (501/1000)
# Progression:  50.2% (502/1000)
# Progression:  50.3% (503/1000)
# Progression:  50.4% (504/1000)
# Progression:  50.5% (505/1000)
# Progression:  50.6% (506/1000)
# Progression:  50.7% (507/1000)
# Progression:  50.8% (508/1000)
# Progression:  50.9% (509/1000)
# Progression:  51.0% (510/1000)
# Iter 510/1000 | Loss = 199.871644
# Progression:  51.1% (511/1000)
# Progression:  51.2% (512/1000)
# Progression:  51.3% (513/1000)
# Progression:  51.4% (514/1000)
# Progression:  51.5% (515/1000)
# Progression:  51.6% (516/1000)
# Progression:  51.7% (517/1000)
# Progression:  51.8% (518/1000)
# Progression:  51.9% (519/1000)
# Progression:  52.0% (520/1000)
# Iter 520/1000 | Loss = 185.709993
# Progression:  52.1% (521/1000)
# Progression:  52.2% (522/1000)
# Progression:  52.3% (523/1000)
# Progression:  52.4% (524/1000)
# Progression:  52.5% (525/1000)
# Progression:  52.6% (526/1000)
# Progression:  52.7% (527/1000)
# Progression:  52.8% (528/1000)
# Progression:  52.9% (529/1000)
# Progression:  53.0% (530/1000)
# Iter 530/1000 | Loss = 172.640582
# Progression:  53.1% (531/1000)
# Progression:  53.2% (532/1000)
# Progression:  53.3% (533/1000)
# Progression:  53.4% (534/1000)
# Progression:  53.5% (535/1000)
# Progression:  53.6% (536/1000)
# Progression:  53.7% (537/1000)
# Progression:  53.8% (538/1000)
# Progression:  53.9% (539/1000)
# Progression:  54.0% (540/1000)
# Iter 540/1000 | Loss = 160.569411
# Progression:  54.1% (541/1000)
# Progression:  54.2% (542/1000)
# Progression:  54.3% (543/1000)
# Progression:  54.4% (544/1000)
# Progression:  54.5% (545/1000)
# Progression:  54.6% (546/1000)
# Progression:  54.7% (547/1000)
# Progression:  54.8% (548/1000)
# Progression:  54.9% (549/1000)
# Progression:  55.0% (550/1000)
# Iter 550/1000 | Loss = 149.411540
# Progression:  55.1% (551/1000)
# Progression:  55.2% (552/1000)
# Progression:  55.3% (553/1000)
# Progression:  55.4% (554/1000)
# Progression:  55.5% (555/1000)
# Progression:  55.6% (556/1000)
# Progression:  55.7% (557/1000)
# Progression:  55.8% (558/1000)
# Progression:  55.9% (559/1000)
# Progression:  56.0% (560/1000)
# Iter 560/1000 | Loss = 139.090127
# Progression:  56.1% (561/1000)
# Progression:  56.2% (562/1000)
# Progression:  56.3% (563/1000)
# Progression:  56.4% (564/1000)
# Progression:  56.5% (565/1000)
# Progression:  56.6% (566/1000)
# Progression:  56.7% (567/1000)
# Progression:  56.8% (568/1000)
# Progression:  56.9% (569/1000)
# Progression:  57.0% (570/1000)
# Iter 570/1000 | Loss = 129.535576
# Progression:  57.1% (571/1000)
# Progression:  57.2% (572/1000)
# Progression:  57.3% (573/1000)
# Progression:  57.4% (574/1000)
# Progression:  57.5% (575/1000)
# Progression:  57.6% (576/1000)
# Progression:  57.7% (577/1000)
# Progression:  57.8% (578/1000)
# Progression:  57.9% (579/1000)
# Progression:  58.0% (580/1000)
# Iter 580/1000 | Loss = 120.684783
# Progression:  58.1% (581/1000)
# Progression:  58.2% (582/1000)
# Progression:  58.3% (583/1000)
# Progression:  58.4% (584/1000)
# Progression:  58.5% (585/1000)
# Progression:  58.6% (586/1000)
# Progression:  58.7% (587/1000)
# Progression:  58.8% (588/1000)
# Progression:  58.9% (589/1000)
# Progression:  59.0% (590/1000)
# Iter 590/1000 | Loss = 112.480461
# Progression:  59.1% (591/1000)
# Progression:  59.2% (592/1000)
# Progression:  59.3% (593/1000)
# Progression:  59.4% (594/1000)
# Progression:  59.5% (595/1000)
# Progression:  59.6% (596/1000)
# Progression:  59.7% (597/1000)
# Progression:  59.8% (598/1000)
# Progression:  59.9% (599/1000)
# Progression:  60.0% (600/1000)
# Iter 600/1000 | Loss = 104.870549
# Progression:  60.1% (601/1000)
# Progression:  60.2% (602/1000)
# Progression:  60.3% (603/1000)
# Progression:  60.4% (604/1000)
# Progression:  60.5% (605/1000)
# Progression:  60.6% (606/1000)
# Progression:  60.7% (607/1000)
# Progression:  60.8% (608/1000)
# Progression:  60.9% (609/1000)
# Progression:  61.0% (610/1000)
# Iter 610/1000 | Loss = 97.807678
# Progression:  61.1% (611/1000)
# Progression:  61.2% (612/1000)
# Progression:  61.3% (613/1000)
# Progression:  61.4% (614/1000)
# Progression:  61.5% (615/1000)
# Progression:  61.6% (616/1000)
# Progression:  61.7% (617/1000)
# Progression:  61.8% (618/1000)
# Progression:  61.9% (619/1000)
# Progression:  62.0% (620/1000)
# Iter 620/1000 | Loss = 91.248704
# Progression:  62.1% (621/1000)
# Progression:  62.2% (622/1000)
# Progression:  62.3% (623/1000)
# Progression:  62.4% (624/1000)
# Progression:  62.5% (625/1000)
# Progression:  62.6% (626/1000)
# Progression:  62.7% (627/1000)
# Progression:  62.8% (628/1000)
# Progression:  62.9% (629/1000)
# Progression:  63.0% (630/1000)
# Iter 630/1000 | Loss = 85.154286
# Progression:  63.1% (631/1000)
# Progression:  63.2% (632/1000)
# Progression:  63.3% (633/1000)
# Progression:  63.4% (634/1000)
# Progression:  63.5% (635/1000)
# Progression:  63.6% (636/1000)
# Progression:  63.7% (637/1000)
# Progression:  63.8% (638/1000)
# Progression:  63.9% (639/1000)
# Progression:  64.0% (640/1000)
# Iter 640/1000 | Loss = 79.488513
# Progression:  64.1% (641/1000)
# Progression:  64.2% (642/1000)
# Progression:  64.3% (643/1000)
# Progression:  64.4% (644/1000)
# Progression:  64.5% (645/1000)
# Progression:  64.6% (646/1000)
# Progression:  64.7% (647/1000)
# Progression:  64.8% (648/1000)
# Progression:  64.9% (649/1000)
# Progression:  65.0% (650/1000)
# Iter 650/1000 | Loss = 74.218571
# Progression:  65.1% (651/1000)
# Progression:  65.2% (652/1000)
# Progression:  65.3% (653/1000)
# Progression:  65.4% (654/1000)
# Progression:  65.5% (655/1000)
# Progression:  65.6% (656/1000)
# Progression:  65.7% (657/1000)
# Progression:  65.8% (658/1000)
# Progression:  65.9% (659/1000)
# Progression:  66.0% (660/1000)
# Iter 660/1000 | Loss = 69.314444
# Progression:  66.1% (661/1000)
# Progression:  66.2% (662/1000)
# Progression:  66.3% (663/1000)
# Progression:  66.4% (664/1000)
# Progression:  66.5% (665/1000)
# Progression:  66.6% (666/1000)
# Progression:  66.7% (667/1000)
# Progression:  66.8% (668/1000)
# Progression:  66.9% (669/1000)
# Progression:  67.0% (670/1000)
# Iter 670/1000 | Loss = 64.748649
# Progression:  67.1% (671/1000)
# Progression:  67.2% (672/1000)
# Progression:  67.3% (673/1000)
# Progression:  67.4% (674/1000)
# Progression:  67.5% (675/1000)
# Progression:  67.6% (676/1000)
# Progression:  67.7% (677/1000)
# Progression:  67.8% (678/1000)
# Progression:  67.9% (679/1000)
# Progression:  68.0% (680/1000)
# Iter 680/1000 | Loss = 60.495995
# Progression:  68.1% (681/1000)
# Progression:  68.2% (682/1000)
# Progression:  68.3% (683/1000)
# Progression:  68.4% (684/1000)
# Progression:  68.5% (685/1000)
# Progression:  68.6% (686/1000)
# Progression:  68.7% (687/1000)
# Progression:  68.8% (688/1000)
# Progression:  68.9% (689/1000)
# Progression:  69.0% (690/1000)
# Iter 690/1000 | Loss = 56.533372
# Progression:  69.1% (691/1000)
# Progression:  69.2% (692/1000)
# Progression:  69.3% (693/1000)
# Progression:  69.4% (694/1000)
# Progression:  69.5% (695/1000)
# Progression:  69.6% (696/1000)
# Progression:  69.7% (697/1000)
# Progression:  69.8% (698/1000)
# Progression:  69.9% (699/1000)
# Progression:  70.0% (700/1000)
# Iter 700/1000 | Loss = 52.839558
# Progression:  70.1% (701/1000)
# Progression:  70.2% (702/1000)
# Progression:  70.3% (703/1000)
# Progression:  70.4% (704/1000)
# Progression:  70.5% (705/1000)
# Progression:  70.6% (706/1000)
# Progression:  70.7% (707/1000)
# Progression:  70.8% (708/1000)
# Progression:  70.9% (709/1000)
# Progression:  71.0% (710/1000)
# Iter 710/1000 | Loss = 49.395047
# Progression:  71.1% (711/1000)
# Progression:  71.2% (712/1000)
# Progression:  71.3% (713/1000)
# Progression:  71.4% (714/1000)
# Progression:  71.5% (715/1000)
# Progression:  71.6% (716/1000)
# Progression:  71.7% (717/1000)
# Progression:  71.8% (718/1000)
# Progression:  71.9% (719/1000)
# Progression:  72.0% (720/1000)
# Iter 720/1000 | Loss = 46.181893
# Progression:  72.1% (721/1000)
# Progression:  72.2% (722/1000)
# Progression:  72.3% (723/1000)
# Progression:  72.4% (724/1000)
# Progression:  72.5% (725/1000)
# Progression:  72.6% (726/1000)
# Progression:  72.7% (727/1000)
# Progression:  72.8% (728/1000)
# Progression:  72.9% (729/1000)
# Progression:  73.0% (730/1000)
# Iter 730/1000 | Loss = 43.183575
# Progression:  73.1% (731/1000)
# Progression:  73.2% (732/1000)
# Progression:  73.3% (733/1000)
# Progression:  73.4% (734/1000)
# Progression:  73.5% (735/1000)
# Progression:  73.6% (736/1000)
# Progression:  73.7% (737/1000)
# Progression:  73.8% (738/1000)
# Progression:  73.9% (739/1000)
# Progression:  74.0% (740/1000)
# Iter 740/1000 | Loss = 40.384865
# Progression:  74.1% (741/1000)
# Progression:  74.2% (742/1000)
# Progression:  74.3% (743/1000)
# Progression:  74.4% (744/1000)
# Progression:  74.5% (745/1000)
# Progression:  74.6% (746/1000)
# Progression:  74.7% (747/1000)
# Progression:  74.8% (748/1000)
# Progression:  74.9% (749/1000)
# Progression:  75.0% (750/1000)
# Iter 750/1000 | Loss = 37.771718
# Progression:  75.1% (751/1000)
# Progression:  75.2% (752/1000)
# Progression:  75.3% (753/1000)
# Progression:  75.4% (754/1000)
# Progression:  75.5% (755/1000)
# Progression:  75.6% (756/1000)
# Progression:  75.7% (757/1000)
# Progression:  75.8% (758/1000)
# Progression:  75.9% (759/1000)
# Progression:  76.0% (760/1000)
# Iter 760/1000 | Loss = 35.331171
# Progression:  76.1% (761/1000)
# Progression:  76.2% (762/1000)
# Progression:  76.3% (763/1000)
# Progression:  76.4% (764/1000)
# Progression:  76.5% (765/1000)
# Progression:  76.6% (766/1000)
# Progression:  76.7% (767/1000)
# Progression:  76.8% (768/1000)
# Progression:  76.9% (769/1000)
# Progression:  77.0% (770/1000)
# Iter 770/1000 | Loss = 33.051249
# Progression:  77.1% (771/1000)
# Progression:  77.2% (772/1000)
# Progression:  77.3% (773/1000)
# Progression:  77.4% (774/1000)
# Progression:  77.5% (775/1000)
# Progression:  77.6% (776/1000)
# Progression:  77.7% (777/1000)
# Progression:  77.8% (778/1000)
# Progression:  77.9% (779/1000)
# Progression:  78.0% (780/1000)
# Iter 780/1000 | Loss = 30.920880
# Progression:  78.1% (781/1000)
# Progression:  78.2% (782/1000)
# Progression:  78.3% (783/1000)
# Progression:  78.4% (784/1000)
# Progression:  78.5% (785/1000)
# Progression:  78.6% (786/1000)
# Progression:  78.7% (787/1000)
# Progression:  78.8% (788/1000)
# Progression:  78.9% (789/1000)
# Progression:  79.0% (790/1000)
# Iter 790/1000 | Loss = 28.929822
# Progression:  79.1% (791/1000)
# Progression:  79.2% (792/1000)
# Progression:  79.3% (793/1000)
# Progression:  79.4% (794/1000)
# Progression:  79.5% (795/1000)
# Progression:  79.6% (796/1000)
# Progression:  79.7% (797/1000)
# Progression:  79.8% (798/1000)
# Progression:  79.9% (799/1000)
# Progression:  80.0% (800/1000)
# Iter 800/1000 | Loss = 27.068592
# Progression:  80.1% (801/1000)
# Progression:  80.2% (802/1000)
# Progression:  80.3% (803/1000)
# Progression:  80.4% (804/1000)
# Progression:  80.5% (805/1000)
# Progression:  80.6% (806/1000)
# Progression:  80.7% (807/1000)
# Progression:  80.8% (808/1000)
# Progression:  80.9% (809/1000)
# Progression:  81.0% (810/1000)
# Iter 810/1000 | Loss = 25.328404
# Progression:  81.1% (811/1000)
# Progression:  81.2% (812/1000)
# Progression:  81.3% (813/1000)
# Progression:  81.4% (814/1000)
# Progression:  81.5% (815/1000)
# Progression:  81.6% (816/1000)
# Progression:  81.7% (817/1000)
# Progression:  81.8% (818/1000)
# Progression:  81.9% (819/1000)
# Progression:  82.0% (820/1000)
# Iter 820/1000 | Loss = 23.701113
# Progression:  82.1% (821/1000)
# Progression:  82.2% (822/1000)
# Progression:  82.3% (823/1000)
# Progression:  82.4% (824/1000)
# Progression:  82.5% (825/1000)
# Progression:  82.6% (826/1000)
# Progression:  82.7% (827/1000)
# Progression:  82.8% (828/1000)
# Progression:  82.9% (829/1000)
# Progression:  83.0% (830/1000)
# Iter 830/1000 | Loss = 22.179163
# Progression:  83.1% (831/1000)
# Progression:  83.2% (832/1000)
# Progression:  83.3% (833/1000)
# Progression:  83.4% (834/1000)
# Progression:  83.5% (835/1000)
# Progression:  83.6% (836/1000)
# Progression:  83.7% (837/1000)
# Progression:  83.8% (838/1000)
# Progression:  83.9% (839/1000)
# Progression:  84.0% (840/1000)
# Iter 840/1000 | Loss = 20.755540
# Progression:  84.1% (841/1000)
# Progression:  84.2% (842/1000)
# Progression:  84.3% (843/1000)
# Progression:  84.4% (844/1000)
# Progression:  84.5% (845/1000)
# Progression:  84.6% (846/1000)
# Progression:  84.7% (847/1000)
# Progression:  84.8% (848/1000)
# Progression:  84.9% (849/1000)
# Progression:  85.0% (850/1000)
# Iter 850/1000 | Loss = 19.423728
# Progression:  85.1% (851/1000)
# Progression:  85.2% (852/1000)
# Progression:  85.3% (853/1000)
# Progression:  85.4% (854/1000)
# Progression:  85.5% (855/1000)
# Progression:  85.6% (856/1000)
# Progression:  85.7% (857/1000)
# Progression:  85.8% (858/1000)
# Progression:  85.9% (859/1000)
# Progression:  86.0% (860/1000)
# Iter 860/1000 | Loss = 18.177672
# Progression:  86.1% (861/1000)
# Progression:  86.2% (862/1000)
# Progression:  86.3% (863/1000)
# Progression:  86.4% (864/1000)
# Progression:  86.5% (865/1000)
# Progression:  86.6% (866/1000)
# Progression:  86.7% (867/1000)
# Progression:  86.8% (868/1000)
# Progression:  86.9% (869/1000)
# Progression:  87.0% (870/1000)
# Iter 870/1000 | Loss = 17.011742
# Progression:  87.1% (871/1000)
# Progression:  87.2% (872/1000)
# Progression:  87.3% (873/1000)
# Progression:  87.4% (874/1000)
# Progression:  87.5% (875/1000)
# Progression:  87.6% (876/1000)
# Progression:  87.7% (877/1000)
# Progression:  87.8% (878/1000)
# Progression:  87.9% (879/1000)
# Progression:  88.0% (880/1000)
# Iter 880/1000 | Loss = 15.920699
# Progression:  88.1% (881/1000)
# Progression:  88.2% (882/1000)
# Progression:  88.3% (883/1000)
# Progression:  88.4% (884/1000)
# Progression:  88.5% (885/1000)
# Progression:  88.6% (886/1000)
# Progression:  88.7% (887/1000)
# Progression:  88.8% (888/1000)
# Progression:  88.9% (889/1000)
# Progression:  89.0% (890/1000)
# Iter 890/1000 | Loss = 14.899665
# Progression:  89.1% (891/1000)
# Progression:  89.2% (892/1000)
# Progression:  89.3% (893/1000)
# Progression:  89.4% (894/1000)
# Progression:  89.5% (895/1000)
# Progression:  89.6% (896/1000)
# Progression:  89.7% (897/1000)
# Progression:  89.8% (898/1000)
# Progression:  89.9% (899/1000)
# Progression:  90.0% (900/1000)
# Iter 900/1000 | Loss = 13.944097
# Progression:  90.1% (901/1000)
# Progression:  90.2% (902/1000)
# Progression:  90.3% (903/1000)
# Progression:  90.4% (904/1000)
# Progression:  90.5% (905/1000)
# Progression:  90.6% (906/1000)
# Progression:  90.7% (907/1000)
# Progression:  90.8% (908/1000)
# Progression:  90.9% (909/1000)
# Progression:  91.0% (910/1000)
# Iter 910/1000 | Loss = 13.049763
# Progression:  91.1% (911/1000)
# Progression:  91.2% (912/1000)
# Progression:  91.3% (913/1000)
# Progression:  91.4% (914/1000)
# Progression:  91.5% (915/1000)
# Progression:  91.6% (916/1000)
# Progression:  91.7% (917/1000)
# Progression:  91.8% (918/1000)
# Progression:  91.9% (919/1000)
# Progression:  92.0% (920/1000)
# Iter 920/1000 | Loss = 12.212717
# Progression:  92.1% (921/1000)
# Progression:  92.2% (922/1000)
# Progression:  92.3% (923/1000)
# Progression:  92.4% (924/1000)
# Progression:  92.5% (925/1000)
# Progression:  92.6% (926/1000)
# Progression:  92.7% (927/1000)
# Progression:  92.8% (928/1000)
# Progression:  92.9% (929/1000)
# Progression:  93.0% (930/1000)
# Iter 930/1000 | Loss = 11.429277
# Progression:  93.1% (931/1000)
# Progression:  93.2% (932/1000)
# Progression:  93.3% (933/1000)
# Progression:  93.4% (934/1000)
# Progression:  93.5% (935/1000)
# Progression:  93.6% (936/1000)
# Progression:  93.7% (937/1000)
# Progression:  93.8% (938/1000)
# Progression:  93.9% (939/1000)
# Progression:  94.0% (940/1000)
# Iter 940/1000 | Loss = 10.696009
# Progression:  94.1% (941/1000)
# Progression:  94.2% (942/1000)
# Progression:  94.3% (943/1000)
# Progression:  94.4% (944/1000)
# Progression:  94.5% (945/1000)
# Progression:  94.6% (946/1000)
# Progression:  94.7% (947/1000)
# Progression:  94.8% (948/1000)
# Progression:  94.9% (949/1000)
# Progression:  95.0% (950/1000)
# Iter 950/1000 | Loss = 10.009706
# Progression:  95.1% (951/1000)
# Progression:  95.2% (952/1000)
# Progression:  95.3% (953/1000)
# Progression:  95.4% (954/1000)
# Progression:  95.5% (955/1000)
# Progression:  95.6% (956/1000)
# Progression:  95.7% (957/1000)
# Progression:  95.8% (958/1000)
# Progression:  95.9% (959/1000)
# Progression:  96.0% (960/1000)
# Iter 960/1000 | Loss = 9.367375
# Progression:  96.1% (961/1000)
# Progression:  96.2% (962/1000)
# Progression:  96.3% (963/1000)
# Progression:  96.4% (964/1000)
# Progression:  96.5% (965/1000)
# Progression:  96.6% (966/1000)
# Progression:  96.7% (967/1000)
# Progression:  96.8% (968/1000)
# Progression:  96.9% (969/1000)
# Progression:  97.0% (970/1000)
# Iter 970/1000 | Loss = 8.766217
# Progression:  97.1% (971/1000)
# Progression:  97.2% (972/1000)
# Progression:  97.3% (973/1000)
# Progression:  97.4% (974/1000)
# Progression:  97.5% (975/1000)
# Progression:  97.6% (976/1000)
# Progression:  97.7% (977/1000)
# Progression:  97.8% (978/1000)
# Progression:  97.9% (979/1000)
# Progression:  98.0% (980/1000)
# Iter 980/1000 | Loss = 8.203619
# Progression:  98.1% (981/1000)
# Progression:  98.2% (982/1000)
# Progression:  98.3% (983/1000)
# Progression:  98.4% (984/1000)
# Progression:  98.5% (985/1000)
# Progression:  98.6% (986/1000)
# Progression:  98.7% (987/1000)
# Progression:  98.8% (988/1000)
# Progression:  98.9% (989/1000)
# Progression:  99.0% (990/1000)
# Iter 990/1000 | Loss = 7.677137
# Progression:  99.1% (991/1000)
# Progression:  99.2% (992/1000)
# Progression:  99.3% (993/1000)
# Progression:  99.4% (994/1000)
# Progression:  99.5% (995/1000)
# Progression:  99.6% (996/1000)
# Progression:  99.7% (997/1000)
# Progression:  99.8% (998/1000)
# Progression:  99.9% (999/1000)
# Progression: 100.0% (1000/1000)
# Iter 1000/1000 | Loss = 7.184484
# Paramètres Heston calibrés:
# kappa    0.078495
# theta    0.276484
# sigma    2.560915
# rho     -0.762096
# v0       0.166482
# Name: valeur, dtype: float64

# %% [markdown]
# ## Étape 3 — Surfaces analytiques Carr-Madan & IV

# %%
K_grid = np.arange(S0_ref - span_mc, S0_ref + span_mc + step_strike, step_strike)
T_grid = np.linspace(0.1, min(iv_T_max, years_ahead), n_maturities)
print(f"Grille strikes: {len(K_grid)} points | Maturités: {len(T_grid)}")

params_cm = HestonParams(
    kappa=torch.tensor(calib_params['kappa'], dtype=torch.float64),
    theta=torch.tensor(calib_params['theta'], dtype=torch.float64),
    sigma=torch.tensor(calib_params['sigma'], dtype=torch.float64),
    rho=torch.tensor(calib_params['rho'], dtype=torch.float64),
    v0=torch.tensor(calib_params['v0'], dtype=torch.float64),
)

call_prices_cm = np.zeros((len(T_grid), len(K_grid)))
put_prices_cm = np.zeros_like(call_prices_cm)
Ks_t = torch.tensor(K_grid, dtype=torch.float64)

for i, T_val in enumerate(T_grid):
    call_anal = carr_madan_call_torch(S0_ref, rf_rate, div_yield, float(T_val), params_cm, Ks_t)
    discount_factor = torch.exp(-torch.tensor(rf_rate * T_val, dtype=torch.float64))
    forward_factor = torch.exp(-torch.tensor(div_yield * T_val, dtype=torch.float64))
    put_anal = call_anal - S0_ref * forward_factor + Ks_t * discount_factor
    call_prices_cm[i, :] = call_anal.detach().cpu().numpy()
    put_prices_cm[i, :] = put_anal.detach().cpu().numpy()

print("Prix Carr-Madan calculés.")

call_iv_cm = np.zeros_like(call_prices_cm)
for i, T_val in enumerate(T_grid):
    for j, K_val in enumerate(K_grid):
        call_iv_cm[i, j] = implied_vol_option(call_prices_cm[i, j], S0_ref, K_val, T_val, rf_rate, "call")

KK_cm, TT_cm = np.meshgrid(K_grid, T_grid)
fig_iv_calls_cm = go.Figure(data=[go.Surface(x=KK_cm, y=TT_cm, z=call_iv_cm, colorscale='Viridis')])
fig_iv_calls_cm.update_layout(title=f"IV Surface Calls BS (Carr-Madan) - {ticker}", scene=dict(xaxis_title='Strike K', yaxis_title='Maturité (années)', zaxis_title='IV'), height=600)
fig_iv_calls_cm.show()

market_iv_df = calls_df.dropna(subset=["iv_market"]).copy()
market_iv_df = market_iv_df[(market_iv_df["T"] >= MIN_IV_MATURITY) & (market_iv_df["iv_market"] > 0)]
if len(market_iv_df) >= 5:
    points = market_iv_df[["K", "T"]].to_numpy()
    values = market_iv_df["iv_market"].to_numpy()
    market_iv_surface = griddata(points, values, (KK_cm, TT_cm), method="linear")
    if market_iv_surface is None or np.all(np.isnan(market_iv_surface)):
        market_iv_surface = griddata(points, values, (KK_cm, TT_cm), method="nearest")
    else:
        nan_mask = np.isnan(market_iv_surface)
        if nan_mask.any():
            market_iv_surface[nan_mask] = griddata(points, values, (KK_cm[nan_mask], TT_cm[nan_mask]), method="nearest")
    fig_iv_market = go.Figure(data=[go.Surface(x=KK_cm, y=TT_cm, z=market_iv_surface, colorscale='Plasma')])
    fig_iv_market.update_layout(title=f"IV Surface Calls (Marché) - {ticker}", scene=dict(xaxis_title='Strike K', yaxis_title='Maturité (années)', zaxis_title='IV'), height=600)
    fig_iv_market.show()
else:
    print("Pas assez de points IV marché pour construire une surface.")
# Out:
# Grille strikes: 41 points | Maturités: 40
# Prix Carr-Madan calculés.

# %% [markdown]
# ## Étape 4 — Pricing Monte Carlo Heston

# %%
n_points_mc = int(2 * span_mc / step_strike) + 1
S_grid_mc = np.linspace(S0_ref - span_mc, S0_ref + span_mc, n_points_mc)
K_grid_mc = np.linspace(S0_ref - span_mc, S0_ref + span_mc, n_points_mc)
n_steps_mc = 252#max(int(T_mc * 365 * 2), 252)

print(f"Grille MC: {len(S_grid_mc)} x {len(K_grid_mc)} (T = {T_mc:.2f} ans, n_steps = {n_steps_mc})")

call_prices_mc = np.zeros((len(S_grid_mc), len(K_grid_mc)))
put_prices_mc = np.zeros_like(call_prices_mc)

for i, S_val in enumerate(S_grid_mc):
    for j, K_val in enumerate(K_grid_mc):
        call_prices_mc[i, j] = heston_mc_pricer(
            S_val,
            K_val,
            T_mc,
            rf_rate,
            calib_params['v0'],
            calib_params['theta'],
            calib_params['kappa'],
            calib_params['sigma'],
            calib_params['rho'],
            n_paths=n_paths,
            n_steps=n_steps_mc,
            option_type="call",
        )
        put_prices_mc[i, j] = heston_mc_pricer(
            S_val,
            K_val,
            T_mc,
            rf_rate,
            calib_params['v0'],
            calib_params['theta'],
            calib_params['kappa'],
            calib_params['sigma'],
            calib_params['rho'],
            n_paths=n_paths,
            n_steps=n_steps_mc,
            option_type="put",
        )

fig_call_mc = go.Figure(data=go.Heatmap(z=call_prices_mc, x=K_grid_mc, y=S_grid_mc, colorscale='Viridis', colorbar=dict(title='Call MC')))
fig_call_mc.update_layout(title=f"Heatmap Prix Calls Heston (MC, T={T_mc:.2f}) - {ticker}", xaxis_title='Strike K', yaxis_title='Spot S', height=500)
fig_call_mc.show()

fig_put_mc = go.Figure(data=go.Heatmap(z=put_prices_mc, x=K_grid_mc, y=S_grid_mc, colorscale='Viridis', colorbar=dict(title='Put MC')))
fig_put_mc.update_layout(title=f"Heatmap Prix Puts Heston (MC, T={T_mc:.2f}) - {ticker}", xaxis_title='Strike K', yaxis_title='Spot S', height=500)
fig_put_mc.show()
# Out:
# Grille MC: 41 x 41 (T = 0.86 ans, n_steps = 252)

# %% [markdown]
# ## Étape 5 — Comparaison Monte Carlo vs Carr-Madan

# %%
idx_S = len(S_grid_mc) // 2
S_compare = S_grid_mc[idx_S]
print(f"Spot sélectionné pour la comparaison: {S_compare:.2f}")

params_cm_compare = HestonParams(
    kappa=torch.tensor(calib_params['kappa'], dtype=torch.float64),
    theta=torch.tensor(calib_params['theta'], dtype=torch.float64),
    sigma=torch.tensor(calib_params['sigma'], dtype=torch.float64),
    rho=torch.tensor(calib_params['rho'], dtype=torch.float64),
    v0=torch.tensor(calib_params['v0'], dtype=torch.float64),
)

Ks_compare = torch.tensor(K_grid_mc, dtype=torch.float64)
call_anal_compare = carr_madan_call_torch(S_compare, rf_rate, div_yield, T_mc, params_cm_compare, Ks_compare)
discount_factor = torch.exp(-torch.tensor(rf_rate * T_mc, dtype=torch.float64))
forward_factor = torch.exp(-torch.tensor(div_yield * T_mc, dtype=torch.float64))
put_anal_compare = call_anal_compare - S_compare * forward_factor + Ks_compare * discount_factor

call_anal_np = call_anal_compare.detach().cpu().numpy()
put_anal_np = put_anal_compare.detach().cpu().numpy()

# Points marché à superposer (T cible et fenêtre K définie)
market_T_target = 0.86
k_min_plot, k_max_plot = S0_ref - span_mc, S0_ref + span_mc

market_calls_plot = calls_df.copy() if "calls_df" in globals() else calls_df_full.copy()
market_calls_plot = market_calls_plot.dropna(subset=["iv_market"])
market_calls_plot = market_calls_plot[(market_calls_plot["iv_market"] > 0) & (market_calls_plot["T"].round(2) == round(market_T_target, 2))]
market_calls_plot = market_calls_plot[(market_calls_plot["K"] >= k_min_plot) & (market_calls_plot["K"] <= k_max_plot)]
market_calls_plot = market_calls_plot.sort_values(["T", "K"])

market_puts_plot = puts_df.copy() if "puts_df" in globals() else puts_df_full.copy()
market_puts_plot = market_puts_plot.dropna(subset=["iv_market"])
market_puts_plot = market_puts_plot[(market_puts_plot["iv_market"] > 0) & (market_puts_plot["T"].round(2) == round(market_T_target, 2))]
market_puts_plot = market_puts_plot[(market_puts_plot["K"] >= k_min_plot) & (market_puts_plot["K"] <= k_max_plot)]
market_puts_plot = market_puts_plot.sort_values(["T", "K"])

fig_compare = go.Figure()
fig_compare.add_trace(go.Scatter(x=K_grid_mc, y=call_prices_mc[idx_S, :], mode='lines+markers', name='MC Call', line=dict(color='red')))
fig_compare.add_trace(go.Scatter(x=K_grid_mc, y=call_anal_np, mode='lines', name='Carr-Madan Call', line=dict(color='red', dash='dash')))
fig_compare.add_trace(go.Scatter(x=K_grid_mc, y=put_prices_mc[idx_S, :], mode='lines+markers', name='MC Put', line=dict(color='green')))
fig_compare.add_trace(go.Scatter(x=K_grid_mc, y=put_anal_np, mode='lines', name='Carr-Madan Put', line=dict(color='green', dash='dash')))
if len(market_calls_plot):
    fig_compare.add_trace(go.Scatter(x=market_calls_plot['K'], y=market_calls_plot.get('C_mkt', market_calls_plot['price'] if 'price' in market_calls_plot else market_calls_plot['iv_market']), mode='markers', name='Marché Call (T≈0.86)', marker=dict(color='black', size=7, symbol='x'), text=market_calls_plot['T']))
if len(market_puts_plot):
    fig_compare.add_trace(go.Scatter(x=market_puts_plot['K'], y=market_puts_plot.get('P_mkt', market_puts_plot['price'] if 'price' in market_puts_plot else market_puts_plot['iv_market']), mode='markers', name='Marché Put (T≈0.86)', marker=dict(color='purple', size=7, symbol='cross'), text=market_puts_plot['T']))
fig_compare.update_layout(title=f"Comparaison MC vs Analytique (S={S_compare:.2f}, T={T_mc:.2f})", xaxis_title='Strike K', yaxis_title='Prix', height=500, yaxis=dict(range=[0, 250]))
fig_compare.show()

# Tableaux marché filtrés
market_calls = market_calls_plot.sort_values(["T", "K"])[["K", "T", "C_mkt", "iv_market"]]
market_puts = market_puts_plot.sort_values(["T", "K"])[["K", "T", "P_mkt", "iv_market"]]
print(f"Lignes marché CALL (T≈{market_T_target}, K in [{k_min_plot},{k_max_plot}]): {len(market_calls)}")
if len(market_calls):
    display(market_calls.head(50))
else:
    print("Aucune ligne marché (calls) pour ce filtre")

print(f"Lignes marché PUT (T≈{market_T_target}, K in [{k_min_plot},{k_max_plot}]): {len(market_puts)}")
if len(market_puts):
    display(market_puts.head(50))
else:
    print("Aucune ligne marché (puts) pour ce filtre")
# Out:
# Spot sélectionné pour la comparaison: 672.97
# Lignes marché CALL (T≈0.86, K in [652.97,692.97]): 39
#           K     T  C_mkt  iv_market
# 3439  653.0  0.86  62.77     0.2002
# 3440  654.0  0.86  62.09     0.1996
# 3441  655.0  0.86  61.42     0.1990
# 3442  656.0  0.86  60.75     0.1984
# 3443  657.0  0.86  60.09     0.1978
# 3444  658.0  0.86  59.42     0.1972
# 3445  659.0  0.86  58.76     0.1966
# 3446  660.0  0.86  58.11     0.1960
# 3447  661.0  0.86  57.45     0.1954
# 3448  662.0  0.86  56.80     0.1948
# 3449  663.0  0.86  56.14     0.1942
# 3450  664.0  0.86  55.50     0.1936
# 3451  665.0  0.86  55.05     0.1937
# 3452  666.0  0.86  54.22     0.1924
# 3453  667.0  0.86  53.59     0.1919
# 3454  668.0  0.86  52.95     0.1913
# 3455  669.0  0.86  52.31     0.1907
# 3456  670.0  0.86  51.84     0.1905
# 3457  671.0  0.86  51.06     0.1896
# 3458  672.0  0.86  50.44     0.1890
# 3459  673.0  0.86  49.82     0.1884
# 3460  674.0  0.86  49.20     0.1878
# 3461  675.0  0.86  48.59     0.1872
# 3462  676.0  0.86  47.99     0.1867
# 3463  677.0  0.86  47.38     0.1861
# 3464  678.0  0.86  46.78     0.1855
# 3465  679.0  0.86  46.20     0.1850
# 3466  680.0  0.86  45.61     0.1844
# 3467  681.0  0.86  45.02     0.1839
# 3468  682.0  0.86  44.42     0.1833
# 3469  683.0  0.86  43.84     0.1828
# 3470  684.0  0.86  43.39     0.1825
# 3471  685.0  0.86  42.80     0.1820
# 3472  686.0  0.86  42.23     0.1814
# 3473  687.0  0.86  41.66     0.1808
# 3474  688.0  0.86  41.09     0.1803
# 3475  689.0  0.86  40.53     0.1797
# 3476  690.0  0.86  39.97     0.1792
# 3477  691.0  0.86  39.41     0.1786
# Lignes marché PUT (T≈0.86, K in [652.97,692.97]): 39
#           K     T  P_mkt  iv_market
# 3442  653.0  0.86  36.80     0.2010
# 3443  654.0  0.86  37.12     0.2004
# 3444  655.0  0.86  37.45     0.1998
# 3445  656.0  0.86  37.77     0.1992
# 3446  657.0  0.86  38.09     0.1986
# 3447  658.0  0.86  38.42     0.1979
# 3448  659.0  0.86  38.75     0.1974
# 3449  660.0  0.86  39.09     0.1967
# 3450  661.0  0.86  39.42     0.1961
# 3451  662.0  0.86  39.77     0.1955
# 3452  663.0  0.86  40.12     0.1949
# 3453  664.0  0.86  40.47     0.1943
# 3454  665.0  0.86  40.81     0.1937
# 3455  666.0  0.86  41.17     0.1931
# 3456  667.0  0.86  41.52     0.1925
# 3457  668.0  0.86  41.89     0.1920
# 3458  669.0  0.86  42.26     0.1914
# 3459  670.0  0.86  42.63     0.1908
# 3460  671.0  0.86  43.00     0.1902
# 3461  672.0  0.86  43.38     0.1896
# 3462  673.0  0.86  43.77     0.1890
# 3463  674.0  0.86  44.15     0.1884
# 3464  675.0  0.86  44.54     0.1878
# 3465  676.0  0.86  44.94     0.1872
# 3466  677.0  0.86  45.33     0.1867
# 3467  678.0  0.86  45.73     0.1861
# 3468  679.0  0.86  46.14     0.1855
# 3469  680.0  0.86  46.55     0.1849
# 3470  681.0  0.86  46.97     0.1843
# 3471  682.0  0.86  47.38     0.1838
# 3472  683.0  0.86  47.81     0.1832
# 3473  684.0  0.86  48.23     0.1826
# 3474  685.0  0.86  48.67     0.1820
# 3475  686.0  0.86  49.10     0.1815
# 3476  687.0  0.86  49.54     0.1809
# 3477  688.0  0.86  49.98     0.1803
# 3478  689.0  0.86  50.44     0.1797
# 3479  690.0  0.86  50.89     0.1792
# 3480  691.0  0.86  51.35     0.1786
